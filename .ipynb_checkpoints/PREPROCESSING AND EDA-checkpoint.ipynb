# %%
import pandas as pd
import matplotlib.pyplot as plt
from nltk.tokenize import TweetTokenizer
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
import re
import string
from re import sub
import seaborn as sns
from bs4 import BeautifulSoup

# %%
data = pd.read_csv('csvfile_global_twitter.csv', encoding='utf-8')

# %%
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity
# 0      0.190625
# 1      0.100000
# 2      0.000000
# 3      0.350000
# 4      0.556250

# %%
data.shape
# Out:
# (22000, 18)

# %% [markdown]
# ## Data Preprocessing

# %%
data.isnull().sum()
# Out:
# created_at            0
# id                    0
# id_str                0
# original_text         0
# truncated             0
# display_text_range    0
# entities              0
# metadata              0
# source                0
# user                  0
# is_quote_status       0
# retweet_count         0
# favorite_count        0
# favorited             0
# retweeted             0
# lang                  0
# polarity              0
# subjectivity          0
# dtype: int64

# %%
data.dropna(axis = 1, inplace = True)

# %%
data['LENGTH'] = data['original_text'].apply(lambda x:len(str(x).split())) 

data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH
# 0      0.190625      23
# 1      0.100000      24
# 2      0.000000      26
# 3      0.350000      33
# 4      0.556250      21

# %%
# Get the Min, Max and Average text length

len_min, len_max, len_avg = min(data['LENGTH']), max(data['LENGTH']), round(sum(data['LENGTH'])/len(data['LENGTH']))
print('The min {}, max {}, and avg {} features for training .'.format(len_min, len_max, len_avg))
# Out:
# The min 2, max 88, and avg 22 features for training .

# %% [markdown]
# #### 1. Remove Newlines and Tabs

# %%
def remove_newlines_tabs(text):
    """
    This function will remove all the occurrences of newlines, tabs, and combinations like: \\n, \\.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of newlines, tabs, \\n, \\ characters.
        
    Example:
    Input : This is her \\ first day at this place.\n Please,\t Be nice to her.\\n
    Output : This is her first day at this place. Please, Be nice to her. 
    
    """
    
    # Replacing all the occurrences of \n,\\n,\t,\\ with a space.
    Formatted_text = str(text).replace('\\n', ' ').replace('\n', ' ').replace('\t',' ').replace('\\', ' ')
    return Formatted_text

# %%
data["preprocessed"] = data['original_text'].apply(lambda text: remove_newlines_tabs(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  RT @i_ameztoy: Extra random image (I):  Lets f...
# 1      0.100000      24  RT @IndoPac_Info: #China's media explains the ...
# 2      0.000000      26  China even cut off communication, they don't a...
# 3      0.350000      33  Putin to #XiJinping : I told you my friend, Ta...
# 4      0.556250      21  RT @ChinaUncensored: I’m sorry, I thought Taiw...

# %% [markdown]
# #### 2. Strip HTML Tags

# %%
def strip_html_tags(text):
    """ 
    This function will remove all the occurrences of html tags from the text.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of html tags.
        
    Example:
    Input : This is a nice place to live. <IMG>
    Output : This is a nice place to live.  
    """
    # Initiating BeautifulSoup object soup.
    soup = BeautifulSoup(text, "html.parser")
    # Get all the text other than html tags.
    stripped_text = soup.get_text(separator=" ")
    return stripped_text

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: strip_html_tags(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  RT @i_ameztoy: Extra random image (I):  Lets f...
# 1      0.100000      24  RT @IndoPac_Info: #China's media explains the ...
# 2      0.000000      26  China even cut off communication, they don't a...
# 3      0.350000      33  Putin to #XiJinping : I told you my friend, Ta...
# 4      0.556250      21  RT @ChinaUncensored: I’m sorry, I thought Taiw...

# %% [markdown]
# #### 3. Remove Links

# %%
def remove_links(text):
    """
    This function will remove all the occurrences of links.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of all types of links.   
    
    """
    
    # Removing all the occurrences of links that starts with https
    remove_https = re.sub(r'http\S+', '', text)
    # Remove all the occurrences of text that ends with .com
    remove_com = re.sub(r"\ [A-Za-z]*\.com", " ", remove_https)
    return remove_com

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: remove_links(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  RT @i_ameztoy: Extra random image (I):  Lets f...
# 1      0.100000      24  RT @IndoPac_Info: #China's media explains the ...
# 2      0.000000      26  China even cut off communication, they don't a...
# 3      0.350000      33  Putin to #XiJinping : I told you my friend, Ta...
# 4      0.556250      21  RT @ChinaUncensored: I’m sorry, I thought Taiw...

# %% [markdown]
# #### 4. Remove Whitespaces

# %%
def remove_whitespace(text):
    """ This function will remove 
        extra whitespaces from the text
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after extra whitespaces removed .
        
    Example:
    Input : How   are   you   doing   ?
    Output : How are you doing ?     
        
    """
    pattern = re.compile(r'\s+') 
    Without_whitespace = re.sub(pattern, ' ', text)
    # There are some instances where there is no space after '?' & ')', 
    # So I am replacing these with one space so that It will not consider two words as one token.
    text = Without_whitespace.replace('?', ' ? ').replace(')', ') ')
    return text

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: remove_whitespace(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  RT @i_ameztoy: Extra random image (I) : Lets f...
# 1      0.100000      24  RT @IndoPac_Info: #China's media explains the ...
# 2      0.000000      26  China even cut off communication, they don't a...
# 3      0.350000      33  Putin to #XiJinping : I told you my friend, Ta...
# 4      0.556250      21  RT @ChinaUncensored: I’m sorry, I thought Taiw...

# %% [markdown]
# #### 5. Case Conversion / Lower casing

# %%
def lower_casing_text(text):
    
    """
    The function will convert text into lower case.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
         value: text in lowercase
         
    Example:
    Input : The World is Full of Surprises!
    Output : the world is full of surprises!
    
    """
    # Convert text to lower case
    # lower() - It converts all upperase letter of given string to lowercase.
    text = text.lower()
    return text

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: lower_casing_text(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  rt @i_ameztoy: extra random image (i) : lets f...
# 1      0.100000      24  rt @indopac_info: #china's media explains the ...
# 2      0.000000      26  china even cut off communication, they don't a...
# 3      0.350000      33  putin to #xijinping : i told you my friend, ta...
# 4      0.556250      21  rt @chinauncensored: i’m sorry, i thought taiw...

# %% [markdown]
# #### 6. Remove Special Characters

# %%
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: remove_punctuation(text))
#datatrain["preprocessedAns"] = datatrain["preprocessedAns"].apply(lambda text: remove_newlines_tabs(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  rt iameztoy extra random image i  lets focus i...
# 1      0.100000      24  rt indopacinfo chinas media explains the milit...
# 2      0.000000      26  china even cut off communication they dont anw...
# 3      0.350000      33  putin to xijinping  i told you my friend taiwa...
# 4      0.556250      21  rt chinauncensored i’m sorry i thought taiwan ...

# %% [markdown]
# #### 7. Remove Stopwords

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: remove_stopwords(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  rt iameztoy extra random image lets focus one ...
# 1      0.100000      24  rt indopacinfo chinas media explains military ...
# 2      0.000000      26  china even cut communication dont anwer phonec...
# 3      0.350000      33  putin xijinping told friend taiwan vassal stat...
# 4      0.556250      21  rt chinauncensored i’m sorry thought taiwan in...

# %% [markdown]
# #### 8. Stemming / Text Normalization

# %%
stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: stem_words(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  rt iameztoy extra random imag let focu one spe...
# 1      0.100000      24  rt indopacinfo china media explain militari re...
# 2      0.000000      26  china even cut commun dont anwer phonecal us c...
# 3      0.350000      33  putin xijinp told friend taiwan vassal state i...
# 4      0.556250      21  rt chinauncensor i’m sorri thought taiwan inde...

# %% [markdown]
# #### 9. Lemmatization / Text Normalization

# %%
lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

# %%
data["preprocessed"] = data["preprocessed"].apply(lambda text: lemmatize_words(text))
data.head()
# Out:
#                   created_at                   id               id_str  \
# 0  2022-08-07 22:31:20+00:00  1556407673284861952  1556407673284861952
# 1  2022-08-07 22:31:16+00:00  1556407654373027840  1556407654373027840
# 2  2022-08-07 22:31:07+00:00  1556407616208773122  1556407616208773120
# 3  2022-08-07 22:31:06+00:00  1556407614602461185  1556407614602461184
# 4  2022-08-07 22:31:04+00:00  1556407604238245889  1556407604238245888
#
#                                        original_text  truncated  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets...      False
# 1  RT @IndoPac_Info: #China's media explains the ...      False
# 2  China even cut off communication, they don't a...      False
# 3  Putin to #XiJinping : I told you my friend, Ta...      False
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw...      False
#
#   display_text_range                                           entities  \
# 0           [0, 143]  {'hashtags': [{'text': 'City', 'indices': [132...
# 1           [0, 140]  {'hashtags': [{'text': 'China', 'indices': [18...
# 2           [0, 161]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 3           [0, 179]  {'hashtags': [{'text': 'XiJinping', 'indices':...
# 4           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                             metadata  \
# 0  {'iso_language_code': 'en', 'result_type': 're...
# 1  {'iso_language_code': 'en', 'result_type': 're...
# 2  {'iso_language_code': 'en', 'result_type': 're...
# 3  {'iso_language_code': 'en', 'result_type': 're...
# 4  {'iso_language_code': 'en', 'result_type': 're...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 user  is_quote_status  \
# 0  {'id': 3418339671, 'id_str': '3418339671', 'na...            False
# 1  {'id': 1003562923, 'id_str': '1003562923', 'na...            False
# 2  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 3  {'id': 1132320481506406400, 'id_str': '1132320...            False
# 4  {'id': 1260798065373523969, 'id_str': '1260798...            False
#
#    retweet_count  favorite_count  favorited  retweeted lang      polarity  \
# 0              2               0      False      False   en -1.250000e-01
# 1            201               0      False      False   en -1.000000e-01
# 2              0               0      False      False   en  0.000000e+00
# 3              0               0      False      False   en  1.000000e-01
# 4            381               0      False      False   en -6.938894e-18
#
#    subjectivity  LENGTH                                       preprocessed
# 0      0.190625      23  rt iameztoy extra random imag let focu one spe...
# 1      0.100000      24  rt indopacinfo china medium explain militari r...
# 2      0.000000      26  china even cut commun dont anwer phonecal u cl...
# 3      0.350000      33  putin xijinp tell friend taiwan vassal state i...
# 4      0.556250      21  rt chinauncensor i’m sorri think taiwan indepe...

# %% [markdown]
# # Exploratory Data Analysis

# %%
def condition(x):
    if x > 0:
        return "positive"
    elif x == 0:
        return "neutral"
    else:
        return 'negative'

# %%
dt = data["preprocessed"]
data["clean"] = dt.values

# %%
data['sentiment'] = data['polarity'].apply(condition)

# %%
print("Document Count")
print(data.groupby('sentiment')['preprocessed'].count())

print("Word Count")
print(data.groupby('sentiment').apply(lambda x: x.preprocessed.apply(lambda x: len(x.split())).sum()))
# Out:
# Document Count
# sentiment
# negative    4833
# neutral     8985
# positive    8182
# Name: preprocessed, dtype: int64
# Word Count
# sentiment
# negative     75604
# neutral     122501
# positive    123043
# dtype: int64

# %%
#Checking for data imbalance

# Function to print height of barcharts on the bars
def barh(ax):
    
    for p in ax.patches:
        val = p.get_height() #height of the bar
        x = p.get_x()+ p.get_width()/2 # x- position 
        y = p.get_y() + p.get_height() + 15 #y-position
        ax.annotate(round(val,2),(x,y))

plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
ax = sns.countplot(data['sentiment'])
barh(ax)
labels = ['negative', 'neutral', 'positive']
plt.subplot(1,2,2)
plt.pie(data.groupby(['sentiment']).count()['preprocessed'],labels=labels, autopct='%1.1f%%')

plt.show()
# Out:
# C:\Users\hp\anaconda3\envs\ResumeParser\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Filter negative tweets
negative_tweets = data[data.sentiment == 'negative']

# %%
data.to_csv('csvfile_global_twitter_processed.csv', encoding='utf-8', index=False)
